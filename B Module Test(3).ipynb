# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# # B | Module Test

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## Part I&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(10 Points)

# %%
# Write your shell commands here
mkdir test
cd test
touch moduleB
git init
git add moduleB
git commit -m "first commit"
git push https://github.com/MajidFonzie/modbtest.git master

# %% [markdown]
# Your solution to this question should **also** include file, submitted alongside this notebook.

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## Part II&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(10 Points)

# %% [markdown]
# #!/bin/bash
# Name='myname'
# Word='myword'
# find -f -i $Name | $path > list.txt
# grep $Word | head -10

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ## Part III&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(30 Points)

# %%
# Write your test cases and comments here
#normal case :
n=100
a=3
#edge case 
n=3
a=3
#uninteded use
n=-10
a=2

# %%
# Write the fixed code here
n=10
a=2

count = 0
i = 1
result = 0
while count<n:
    if i%a == 0:
        result+=i
    count+=1
    i+=1

# %% [markdown]
# Write your debugging steps here

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ## Part IV&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(50 Points)

# %%
# Write your shell commands here
mkdir part4
cd part4/
bash-4.2$ git init
Initialized empty Git repository in /users/5/a1849225/part4/.git/
bash-4.2$ mkdir --parents  directory1/directory2 
bash-4.2$ mkdir --parents directory1/directory3
bash-4.2$ touch directory1/directory2/file1
bash-4.2$ touch directory1/directory2/file2
mkdir directory4
bash-4.2$ touch directory4/file3
bash-4.2$ touch README.md
bash-4.2$ touch LICENSE
git add --all 
bash-4.2$ git commit -m "part4"
git fetch https://github.com/MajidFonzie/modbtest.git
git add directory1/directory2/file1
bash-4.2$ git commit -m "commiting file1"
git branch newfeature
git checkout newfeature

mv directory4/file3 directory3/file3
cp -r  directory1 directory4/directory1_copy
echo 'This program is free software: you can redistribute it and/or modify > it under the terms of the GNU General Public License ...' > LICENSE
git branch newfeature2
bash-4.2$ git checkout newfeature2
 cd directory4

# %% [markdown]
# Your solution to this question should **also** include a file, submitted alongside this notebook.

# %% [markdown]
# <!-- END QUESTION -->
